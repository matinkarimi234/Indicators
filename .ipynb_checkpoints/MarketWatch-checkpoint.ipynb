# %%
import pandas as pd
import numpy as np
import finpy_tse as fpy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [49], in <cell line: 4>()
#       2 import numpy as np
#       3 import finpy_tse as fpy
# ----> 4 from math import abs
#
# ImportError: cannot import name 'abs' from 'math' (unknown location)

# %%
df , df_order_book = fpy.Get_MarketWatch()
df
# Out:
# Save path does not exist, you can handle saving this data by returned dataframe as Excel using ".to_excel()", if you will!
#        Trade Type      Time     Open     High      Low    Close    Final  \
# Ticker
# ورازی       تابلو  12:29:56   1480.0   1540.0   1464.0   1512.0   1530.0
# سپ          تابلو  12:29:57  15970.0  16420.0  15970.0  16300.0  16230.0
# سکرد        تابلو  12:28:21   8870.0   8870.0   8460.0   8570.0   8520.0
# های وب      تابلو  12:29:58   2190.0   2210.0   2160.0   2178.0   2188.0
# زماهان      تابلو  12:29:59   6580.0   6840.0   6420.0   6750.0   6620.0
# ...           ...       ...      ...      ...      ...      ...      ...
# وثوق        تابلو  12:29:50  33200.0  34100.0  33200.0  33600.0  33650.0
# آ س پ       تابلو  12:29:44  11100.0  11390.0  10900.0  11130.0  11190.0
# تفارس       تابلو  12:28:52   2755.0   2820.0   2755.0   2780.0   2775.0
# بشهاب       تابلو  12:29:32  18100.0  19410.0  18100.0  19410.0  19210.0
# سنیر        تابلو  12:29:26  46050.0  48190.0  46050.0  48190.0  47680.0
#
#         Close(%)  Final(%)   Day_UL  ...  No_Sell_R  No_Sell_I  \
# Ticker                               ...
# ورازی       1.07      2.27   1540.0  ...      200.0        5.0
# سپ          0.43      0.00  17040.0  ...        8.0        0.0
# سکرد        0.94      0.35   9080.0  ...       36.0        1.0
# های وب      0.23      0.69   2325.0  ...      309.0        1.0
# زماهان      5.47      3.44   6840.0  ...      201.0        1.0
# ...          ...       ...      ...  ...        ...        ...
# وثوق       -0.74     -0.59  34850.0  ...      158.0        0.0
# آ س پ       3.63      4.19  11490.0  ...      105.0        1.0
# تفارس      -0.96     -1.14   2891.0  ...       41.0        0.0
# بشهاب       4.98      3.89  19410.0  ...      129.0        2.0
# سنیر        6.99      5.86  48190.0  ...      234.0        3.0
#
#                               Name   Market  \
# Ticker
# ورازی                    بیمه رازی     پایه
# سپ      پرداخت الکترونیک سامان کیش     بورس
# سکرد                 سیمان کردستان     بورس
# های وب     داده گسترعصرنوین-های وب     بورس
# زماهان  مجتمع تولید گوشت مرغ ماهان  فرابورس
# ...                            ...      ...
# وثوق        سرمایه گذاری وثوق امین     پایه
# آ س پ                        آ.س.پ  فرابورس
# تفارس       تامین سرمایه خلیج فارس     پایه
# بشهاب           لامپ   پارس  شهاب      بورس
# سنیر            سیمان  سفید نی ریز     بورس
#
#                                           Sector      Share-No    Base-Vol  \
# Ticker
# ورازی   بیمه وصندوق بازنشستگی به جزتامین اجتماعی  1.903945e+10         1.0
# سپ              رایانه و فعالیت های وابسته به آن  1.144000e+10   4576000.0
# سکرد                             سیمان، آهک و گچ  2.200000e+09   1794258.0
# های وب                        اطلاعات و ارتباطات  3.000000e+10  12000000.0
# زماهان                      زراعت و خدمات وابسته  1.130000e+09         1.0
# ...                                          ...           ...         ...
# وثوق                              سرمایه گذاریها  3.200000e+08         1.0
# آ س پ                انبوه سازی، املاک و مستغلات  1.000000e+09         1.0
# تفارس        فعالیتهای کمکی به نهادهای مالی واسط  1.000000e+10         1.0
# بشهاب               ماشین آلات و دستگاه های برقی  7.290000e+08    813449.0
# سنیر                             سیمان، آهک و گچ  2.300000e+08    337079.0
#
#           Market Cap     EPS             Download
# Ticker
# ورازی   2.913036e+13   187.0  1402-07-30 17:47:48
# سپ      1.856712e+14   226.0  1402-07-30 17:47:48
# سکرد    1.874400e+13   773.0  1402-07-30 17:47:48
# های وب  6.564000e+13  1134.0  1402-07-30 17:47:48
# زماهان  7.480600e+12  -156.0  1402-07-30 17:47:48
# ...              ...     ...                  ...
# وثوق    1.076800e+13   542.0  1402-07-30 17:47:48
# آ س پ   1.119000e+13    83.0  1402-07-30 17:47:48
# تفارس   2.775000e+13   125.0  1402-07-30 17:47:48
# بشهاب   1.400409e+13  1819.0  1402-07-30 17:47:48
# سنیر    1.096640e+13  5356.0  1402-07-30 17:47:48
#
# [915 rows x 34 columns]

# %%
df.columns.values.tolist()
# Out:
# ['Trade Type',
#  'Time',
#  'Open',
#  'High',
#  'Low',
#  'Close',
#  'Final',
#  'Close(%)',
#  'Final(%)',
#  'Day_UL',
#  'Day_LL',
#  'Value',
#  'BQ-Value',
#  'SQ-Value',
#  'BQPC',
#  'SQPC',
#  'Volume',
#  'Vol_Buy_R',
#  'Vol_Buy_I',
#  'Vol_Sell_R',
#  'Vol_Sell_I',
#  'No',
#  'No_Buy_R',
#  'No_Buy_I',
#  'No_Sell_R',
#  'No_Sell_I',
#  'Name',
#  'Market',
#  'Sector',
#  'Share-No',
#  'Base-Vol',
#  'Market Cap',
#  'EPS',
#  'Download']

# %%
def strategy(dft):
    
    #P/E
    #dft = dft[((dft['Final'])/(abs(dft['EPS'])) <= 5)]
    
    
#     true == function()
# {
# if((pl) > (pf)) { var tl = (tmax)-(tmin);var pl = (pmax) - (pmin); var cl = (pl) - (pf); if (cl/tl >= 0.7 && pl/tl >= 0.6)
# return true;            
# }
# }
# ()
    tl = (dft['Day_UL'] - dft['Day_LL'])
    pl = (dft['High'] - dft['Low'])
    cl = (pl - dft['Open'])
    dft = dft[(dft['Close'] > dft['Open']) & (((cl/tl) >= 0.7) | ((pl/tl) >= 0.6))]
    

    py = ((dft['Close']*100)/ (dft['Final(%)']+100))
    
    # (pl) > (pc) && (pmax) > (pmin) && (pl) > (py) && (pmax) > (py) && (pf) >= (py) && (pl) > (pmin) && (pl) > (pf) && (pl)/(pf) <1.015 && (pl)/(pf) > 1.005 && (pmax) == (pf) && (tno) >1
    pl = dft['Close']
    pc = dft['Final']
    pmax = dft['High']
    pmin = dft['Low']
    pf = dft['Open']
#     dft = dft[((pl > pc) & (pmax > pmin) & 
#                (pl > py) & (pmax > py) & 
#                (pf >= py) & (pl > pmin) & 
#                (pl > pf) & ((pl/pf) < 1.015) & 
#                ((pl/pf) > 1.005) & (pmax == pf) & ((dft['No']) > 1))]
    
    # (pc) >= (py) && (bvol) < 200000 && (plp) >=1.5
    dft = dft[(pc>= py) &(dft['Base-Vol'] < 200000 )& (dft['Final(%)']>=1.5) & (pl > pc) & (pmax > pmin) & (pl > py) & (pmax > py) & (pf >= py) & (pl > pmin) & (pl > pf) & ((pl/pf) < 1.015)]
    
    
    return dft

# %%
df_final = strategy(df)
df_final
# Out:
#         Trade Type      Time    Open    High     Low   Close   Final  \
# Ticker
# تماوندح      تابلو  12:12:42  3000.0  3008.0  2831.0  3008.0  3000.0
#
#          Close(%)  Final(%)  Day_UL  ...           Market  \
# Ticker                               ...
# تماوندح      4.99      4.71  3008.0  ...  حق تقدم فرابورس
#
#                                       Sector      Share-No  Base-Vol  \
# Ticker
# تماوندح  فعالیتهای کمکی به نهادهای مالی واسط  4.200000e+09       1.0
#
#            Market Cap  EPS             Download     tl     pl      cl
# Ticker
# تماوندح  1.260000e+13  NaN  1402-07-30 17:47:48  286.0  177.0 -2823.0
#
# [1 rows x 37 columns]
